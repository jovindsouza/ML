# %% [markdown]
# # **Import the libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# # **Reading the data**

# %%
df = pd.read_csv('student_evaluation.csv')
df.head()
# Out:
#    instr  class  nb.repeat  attendance  difficulty  ...  Q24  Q25  Q26  Q27  Q28
# 0      1      2          1           0           4  ...    3    3    3    3    3
# 1      1      2          1           1           3  ...    3    3    3    3    3
# 2      1      2          1           2           4  ...    5    5    5    5    5
# 3      1      2          1           1           3  ...    3    3    3    3    3
# 4      1      2          1           0           1  ...    1    1    1    1    1
#
# [5 rows x 33 columns]

# %%
#Statistical summary
df.describe()
# Out:
#              instr        class  ...          Q27          Q28
# count  5820.000000  5820.000000  ...  5820.000000  5820.000000
# mean      2.485567     7.276289  ...     3.154811     3.308076
# std       0.718473     3.688175  ...     1.291872     1.278709
# min       1.000000     1.000000  ...     1.000000     1.000000
# 25%       2.000000     4.000000  ...     2.000000     3.000000
# 50%       3.000000     7.000000  ...     3.000000     3.000000
# 75%       3.000000    10.000000  ...     4.000000     4.000000
# max       3.000000    13.000000  ...     5.000000     5.000000
#
# [8 rows x 33 columns]

# %%
#Checking for Null values if any
df.isnull().sum()
# Out:
# instr         0
# class         0
# nb.repeat     0
# attendance    0
# difficulty    0
# Q1            0
# Q2            0
# Q3            0
# Q4            0
# Q5            0
# Q6            0
# Q7            0
# Q8            0
# Q9            0
# Q10           0
# Q11           0
# Q12           0
# Q13           0
# Q14           0
# Q15           0
# Q16           0
# Q17           0
# Q18           0
# Q19           0
# Q20           0
# Q21           0
# Q22           0
# Q23           0
# Q24           0
# Q25           0
# Q26           0
# Q27           0
# Q28           0
# dtype: int64

# %%
#Starting the initial value of clusters as 2
km= KMeans(n_clusters=2)
km.fit(df)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
pred = km.predict(df)

# %%
#Determination of the count of variables
pd.Series(pred).value_counts()
# Out:
# 0    3148
# 1    2672
# dtype: int64

# %%
#Determine the inertia
km.inertia_
# Out:
# 231353.7586857733

# %%
km.score(df)
# Out:
# -231353.75868577306

# %%
#Finding the differnt k values
SSE = []
for k in range(1,20):
  km = KMeans(n_jobs=-1, n_clusters=k)
  km.fit(df)
  SSE.append(km.inertia_)

SSE
# Out:
# [373025.67285223363,
#  231353.7586857733,
#  180375.76659547855,
#  152888.20644079396,
#  133015.6157763964,
#  119620.25246354294,
#  112463.8763555702,
#  105894.59697825846,
#  101332.4900468311,
#  97524.95485673069,
#  94170.1340222299,
#  91515.92334555982,
#  89254.86030134151,
#  87710.51954649754,
#  86404.04872588193,
#  84526.28134180162,
#  83671.32313545413,
#  82062.04121836412,
#  80963.51819089464]

# %%
#Storing the data in a DataFrame
frame = pd.DataFrame({'Clusters': range(1,20), 'SSE' :SSE })
frame
# Out:
#     Clusters            SSE
# 0          1  373025.672852
# 1          2  231353.758686
# 2          3  180375.766595
# 3          4  152888.145973
# 4          5  133016.516186
# 5          6  119620.319351
# 6          7  112464.030864
# 7          8  105894.822450
# 8          9  101318.571428
# 9         10   97525.567360
# 10        11   94140.164461
# 11        12   91485.223763
# 12        13   89274.382467
# 13        14   87320.071261
# 14        15   86068.085934
# 15        16   84593.864588
# 16        17   83213.673597
# 17        18   81789.081441
# 18        19   80897.429597

# %%
#Plotting the Elbow Curve
plt.figure(figsize=(10,7))
plt.plot(frame.Clusters, frame.SSE, marker='o')
plt.xlabel('no. of Clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# # **We Forgot the scale the data, so repeat the same process by scaling the data**

# %%
#Data Normalization
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
data = ss.fit_transform(df)

# %%
pd.DataFrame(data)
# Out:
#            0         1         2   ...        30        31        32
# 0    -2.06785 -1.430719 -0.402174  ... -0.174852 -0.119845 -0.240948
# 1    -2.06785 -1.430719 -0.402174  ... -0.174852 -0.119845 -0.240948
# 2    -2.06785 -1.430719 -0.402174  ...  1.399225  1.428430  1.323265
# 3    -2.06785 -1.430719 -0.402174  ... -0.174852 -0.119845 -0.240948
# 4    -2.06785 -1.430719 -0.402174  ... -1.748929 -1.668120 -1.805160
# ...       ...       ...       ...  ...       ...       ...       ...
# 5815  0.71607  1.552042 -0.402174  ... -1.748929 -1.668120 -1.805160
# 5816  0.71607  1.552042 -0.402174  ...  1.399225  1.428430  1.323265
# 5817  0.71607  1.552042 -0.402174  ...  1.399225  1.428430  1.323265
# 5818  0.71607  1.552042 -0.402174  ... -1.748929 -1.668120 -1.805160
# 5819  0.71607  1.552042 -0.402174  ... -1.748929 -1.668120 -1.805160
#
# [5820 rows x 33 columns]

# %%
SSE_scaled = []

for k in range(1,20):
  km = KMeans(n_jobs= -1, n_clusters=k)
  km.fit(x)
  SSE_scaled.append(km.inertia_)

# %%
frame_scaled = pd.DataFrame({'Clusters': range(1,20), 'SSE' :SSE })
frame_scaled
# Out:
#     Clusters            SSE
# 0          1  373025.672852
# 1          2  231353.758686
# 2          3  180375.766595
# 3          4  152888.145973
# 4          5  133016.516186
# 5          6  119620.319351
# 6          7  112464.030864
# 7          8  105894.822450
# 8          9  101318.571428
# 9         10   97525.567360
# 10        11   94140.164461
# 11        12   91485.223763
# 12        13   89274.382467
# 13        14   87320.071261
# 14        15   86068.085934
# 15        16   84593.864588
# 16        17   83213.673597
# 17        18   81789.081441
# 18        19   80897.429597

# %%
plt.figure(figsize=(10,7))
plt.plot(frame_scaled.Clusters, frame_scaled.SSE, marker='o')
plt.xlabel('no. of Clusters')
plt.ylabel('Inertia')
plt.show()


print(' \033[1m \033[94m From the above graph we can observe the the ideal value of k lies between 3.0 & 5.0')
# Out:
#    From the above graph we can observe the the ideal value of k lies between 3.0 & 5.0

# %%
#Predicting the values using k = 4
km = KMeans(n_jobs= -1, n_clusters=4)
km.fit(data)
pred = km.predict(data)

# %%
pred
# Out:
# array([0, 0, 1, ..., 1, 3, 3], dtype=int32)

# %%
dataframe = pd.DataFrame(data)
dataframe
# Out:
#            0         1         2   ...        30        31        32
# 0    -2.06785 -1.430719 -0.402174  ... -0.174852 -0.119845 -0.240948
# 1    -2.06785 -1.430719 -0.402174  ... -0.174852 -0.119845 -0.240948
# 2    -2.06785 -1.430719 -0.402174  ...  1.399225  1.428430  1.323265
# 3    -2.06785 -1.430719 -0.402174  ... -0.174852 -0.119845 -0.240948
# 4    -2.06785 -1.430719 -0.402174  ... -1.748929 -1.668120 -1.805160
# ...       ...       ...       ...  ...       ...       ...       ...
# 5815  0.71607  1.552042 -0.402174  ... -1.748929 -1.668120 -1.805160
# 5816  0.71607  1.552042 -0.402174  ...  1.399225  1.428430  1.323265
# 5817  0.71607  1.552042 -0.402174  ...  1.399225  1.428430  1.323265
# 5818  0.71607  1.552042 -0.402174  ... -1.748929 -1.668120 -1.805160
# 5819  0.71607  1.552042 -0.402174  ... -1.748929 -1.668120 -1.805160
#
# [5820 rows x 33 columns]

# %%
dataframe['cluster'] = pred

# %%
dataframe['cluster'].value_counts()
# Out:
# 0    2098
# 2    1670
# 3    1196
# 1     856
# Name: cluster, dtype: int64

# %%
dataframe.head()
# Out:
#          0         1         2         3  ...        30        31        32  cluster
# 0 -2.06785 -1.430719 -0.402174 -1.136118  ... -0.174852 -0.119845 -0.240948        0
# 1 -2.06785 -1.430719 -0.402174 -0.458082  ... -0.174852 -0.119845 -0.240948        0
# 2 -2.06785 -1.430719 -0.402174  0.219954  ...  1.399225  1.428430  1.323265        1
# 3 -2.06785 -1.430719 -0.402174 -0.458082  ... -0.174852 -0.119845 -0.240948        0
# 4 -2.06785 -1.430719 -0.402174 -1.136118  ... -1.748929 -1.668120 -1.805160        3
#
# [5 rows x 34 columns]
